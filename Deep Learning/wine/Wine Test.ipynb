# %%
from keras.models import Sequential 
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd 
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
# seed 값 설정 
seed = 0 
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
# 데이터 입력
df_pre = pd.read_csv('dataset/wine.csv', header = None)
df = df_pre.sample(frac = 1)
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
# 모델 설정 
model = Sequential()
model.add(Dense(30, input_dim = 12, activation = 'relu'))
model.add(Dense(12, activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# 모델 컴파일 
model.compile(loss = 'binary_crossentropy', 
             optimizer = 'adam',
             metrics = ['accuracy'])

# 모델 실행 
model.fit(X,Y, epochs = 200, batch_size = 200)

# 결과 출력 
print("\n Accuracy: %.4f" % (model.evaluate(X,Y)[1]))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0819 15:45:02.819006  7736 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0819 15:45:02.823006  7736 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0819 15:45:02.828007  7736 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0819 15:45:02.893011  7736 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0819 15:45:02.916012  7736 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0819 15:45:02.922012  7736 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0819 15:45:03.042019  7736 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/200
# 6497/6497 [==============================] - 0s 34us/step - loss: 0.3866 - acc: 0.8030
# Epoch 2/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.2724 - acc: 0.9024
# Epoch 3/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.2207 - acc: 0.9324
# Epoch 4/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.2040 - acc: 0.9355
# Epoch 5/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1943 - acc: 0.9378
# Epoch 6/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1859 - acc: 0.9380
# Epoch 7/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1837 - acc: 0.9398
# Epoch 8/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1767 - acc: 0.9410
# Epoch 9/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1742 - acc: 0.9403
# Epoch 10/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1680 - acc: 0.9427
# Epoch 11/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1663 - acc: 0.9451
# Epoch 12/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1621 - acc: 0.9460
# Epoch 13/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1567 - acc: 0.9474
# Epoch 14/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1530 - acc: 0.9467
# Epoch 15/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1530 - acc: 0.9474
# Epoch 16/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1438 - acc: 0.9489
# Epoch 17/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1414 - acc: 0.9492
# Epoch 18/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1352 - acc: 0.9512
# Epoch 19/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1334 - acc: 0.9514
# Epoch 20/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1316 - acc: 0.9518
# Epoch 21/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1293 - acc: 0.9546
# Epoch 22/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1232 - acc: 0.9549
# Epoch 23/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1228 - acc: 0.9554
# Epoch 24/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1224 - acc: 0.9557
# Epoch 25/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1188 - acc: 0.9575
# Epoch 26/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1109 - acc: 0.9609
# Epoch 27/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1112 - acc: 0.9617
# Epoch 28/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1117 - acc: 0.9629
# Epoch 29/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1048 - acc: 0.9651
# Epoch 30/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1053 - acc: 0.9634
# Epoch 31/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1061 - acc: 0.9641
# Epoch 32/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.1002 - acc: 0.9660
# Epoch 33/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0959 - acc: 0.9683
# Epoch 34/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0945 - acc: 0.9683
# Epoch 35/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0923 - acc: 0.9709
# Epoch 36/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0908 - acc: 0.9698
# Epoch 37/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0879 - acc: 0.9726
# Epoch 38/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0846 - acc: 0.9732
# Epoch 39/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0868 - acc: 0.9717
# Epoch 40/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0822 - acc: 0.9744
# Epoch 41/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0887 - acc: 0.9714
# Epoch 42/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0850 - acc: 0.9740
# Epoch 43/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0864 - acc: 0.9709
# Epoch 44/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0775 - acc: 0.9755
# Epoch 45/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0761 - acc: 0.9763
# Epoch 46/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0765 - acc: 0.9766
# Epoch 47/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0727 - acc: 0.9781
# Epoch 48/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0716 - acc: 0.9775
# Epoch 49/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0760 - acc: 0.9754
# Epoch 50/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0756 - acc: 0.9758
# Epoch 51/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0695 - acc: 0.9781
# Epoch 52/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0683 - acc: 0.9789
# Epoch 53/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0751 - acc: 0.9786
# Epoch 54/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0699 - acc: 0.9780
# Epoch 55/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0754 - acc: 0.9763
# Epoch 56/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0745 - acc: 0.9758
# Epoch 57/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0649 - acc: 0.9798
# Epoch 58/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0649 - acc: 0.9800
# Epoch 59/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0668 - acc: 0.9806
# Epoch 60/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0667 - acc: 0.9806
# Epoch 61/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0631 - acc: 0.9814
# Epoch 62/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0627 - acc: 0.9809
# Epoch 63/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0676 - acc: 0.9800
# Epoch 64/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0617 - acc: 0.9821
# Epoch 65/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0622 - acc: 0.9818
# Epoch 66/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0602 - acc: 0.9812
# Epoch 67/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0608 - acc: 0.9821
# Epoch 68/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0611 - acc: 0.9825
# Epoch 69/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0644 - acc: 0.9795
# Epoch 70/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0633 - acc: 0.9809
# Epoch 71/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0621 - acc: 0.9809
# Epoch 72/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0596 - acc: 0.9825
# Epoch 73/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0632 - acc: 0.9806
# Epoch 74/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0608 - acc: 0.9825
# Epoch 75/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0589 - acc: 0.9831
# Epoch 76/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0571 - acc: 0.9834
# Epoch 77/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0572 - acc: 0.9841
# Epoch 78/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0581 - acc: 0.9820
# Epoch 79/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0586 - acc: 0.9834
# Epoch 80/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0563 - acc: 0.9841
# Epoch 81/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0569 - acc: 0.9840
# Epoch 82/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0593 - acc: 0.9838
# Epoch 83/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0564 - acc: 0.9838
# Epoch 84/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0537 - acc: 0.9845
# Epoch 85/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0541 - acc: 0.9843
# Epoch 86/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0555 - acc: 0.9835
# Epoch 87/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0626 - acc: 0.9817
# Epoch 88/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0715 - acc: 0.9800
# Epoch 89/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0584 - acc: 0.9837
# Epoch 90/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0537 - acc: 0.9838
# Epoch 91/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0544 - acc: 0.9843
# Epoch 92/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0582 - acc: 0.9826
# Epoch 93/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0547 - acc: 0.9831
# Epoch 94/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0536 - acc: 0.9851
# Epoch 95/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0566 - acc: 0.9832
# Epoch 96/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0523 - acc: 0.9848
# Epoch 97/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0527 - acc: 0.9840
# Epoch 98/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0532 - acc: 0.9848
# Epoch 99/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0538 - acc: 0.9848
# Epoch 100/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0556 - acc: 0.9841
# Epoch 101/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0565 - acc: 0.9845
# Epoch 102/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0502 - acc: 0.9846
# Epoch 103/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0530 - acc: 0.9840
# Epoch 104/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0544 - acc: 0.9841
# Epoch 105/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0515 - acc: 0.9854
# Epoch 106/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0535 - acc: 0.9851
# Epoch 107/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0516 - acc: 0.9854
# Epoch 108/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0626 - acc: 0.9812
# Epoch 109/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0523 - acc: 0.9849
# Epoch 110/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0505 - acc: 0.9857
# Epoch 111/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0511 - acc: 0.9843
# Epoch 112/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0525 - acc: 0.9855
# Epoch 113/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0538 - acc: 0.9834
# Epoch 114/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0541 - acc: 0.9854
# Epoch 115/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0516 - acc: 0.9843
# Epoch 116/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0500 - acc: 0.9845
# Epoch 117/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0499 - acc: 0.9852
# Epoch 118/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0508 - acc: 0.9858
# Epoch 119/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0545 - acc: 0.9854
# Epoch 120/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0553 - acc: 0.9845
# Epoch 121/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0513 - acc: 0.9858
# Epoch 122/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0484 - acc: 0.9868
# Epoch 123/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0513 - acc: 0.9863
# Epoch 124/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0530 - acc: 0.9849
# Epoch 125/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0539 - acc: 0.9845
# Epoch 126/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0484 - acc: 0.9863
# Epoch 127/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0514 - acc: 0.9851
# Epoch 128/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0546 - acc: 0.9832
# Epoch 129/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0475 - acc: 0.9871
# Epoch 130/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0471 - acc: 0.9865
# Epoch 131/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0503 - acc: 0.9849
# Epoch 132/200
# 6497/6497 [==============================] - 0s 5us/step - loss: 0.0489 - acc: 0.9869
# Epoch 133/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0498 - acc: 0.9852
# Epoch 134/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0503 - acc: 0.9855
# Epoch 135/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0472 - acc: 0.9865
# Epoch 136/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0479 - acc: 0.9875
# Epoch 137/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0473 - acc: 0.9865
# Epoch 138/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0506 - acc: 0.9858
# Epoch 139/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0488 - acc: 0.9860
# Epoch 140/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0477 - acc: 0.9852
# Epoch 141/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0474 - acc: 0.9865
# Epoch 142/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0461 - acc: 0.9871
# Epoch 143/200
# 6497/6497 [==============================] - 0s 5us/step - loss: 0.0506 - acc: 0.9871
# Epoch 144/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0489 - acc: 0.9866
# Epoch 145/200
# 6497/6497 [==============================] - 0s 5us/step - loss: 0.0530 - acc: 0.9857
# Epoch 146/200
# 6497/6497 [==============================] - 0s 5us/step - loss: 0.0556 - acc: 0.9821
# Epoch 147/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0511 - acc: 0.9865
# Epoch 148/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0457 - acc: 0.9869
# Epoch 149/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0490 - acc: 0.9865
# Epoch 150/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0502 - acc: 0.9858
# Epoch 151/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0470 - acc: 0.9869
# Epoch 152/200
# 6497/6497 [==============================] - 0s 5us/step - loss: 0.0489 - acc: 0.9860
# Epoch 153/200
# 6497/6497 [==============================] - 0s 5us/step - loss: 0.0478 - acc: 0.9857
# Epoch 154/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0452 - acc: 0.9874
# Epoch 155/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0458 - acc: 0.9874
# Epoch 156/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0461 - acc: 0.9874
# Epoch 157/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0552 - acc: 0.9848
# Epoch 158/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0509 - acc: 0.9852
# Epoch 159/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0448 - acc: 0.9871
# Epoch 160/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0552 - acc: 0.9834
# Epoch 161/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0438 - acc: 0.9883
# Epoch 162/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0462 - acc: 0.9877
# Epoch 163/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0460 - acc: 0.9877
# Epoch 164/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0442 - acc: 0.9869
# Epoch 165/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0474 - acc: 0.9871
# Epoch 166/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0550 - acc: 0.9851
# Epoch 167/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0473 - acc: 0.9871
# Epoch 168/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0446 - acc: 0.9875
# Epoch 169/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0484 - acc: 0.9860
# Epoch 170/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0534 - acc: 0.9843
# Epoch 171/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0474 - acc: 0.9871
# Epoch 172/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0440 - acc: 0.9881
# Epoch 173/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0481 - acc: 0.9866
# Epoch 174/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0453 - acc: 0.9875
# Epoch 175/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0425 - acc: 0.9888
# Epoch 176/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0445 - acc: 0.9881
# Epoch 177/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0433 - acc: 0.9886
# Epoch 178/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0440 - acc: 0.9889
# Epoch 179/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0445 - acc: 0.9875
# Epoch 180/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0524 - acc: 0.9846
# Epoch 181/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0458 - acc: 0.9877
# Epoch 182/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0438 - acc: 0.9885
# Epoch 183/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0470 - acc: 0.9874
# Epoch 184/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0429 - acc: 0.9889
# Epoch 185/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0435 - acc: 0.9877
# Epoch 186/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0422 - acc: 0.9888
# Epoch 187/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0419 - acc: 0.9889
# Epoch 188/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0420 - acc: 0.9881
# Epoch 189/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0442 - acc: 0.9877
# Epoch 190/200
# 6497/6497 [==============================] - 0s 3us/step - loss: 0.0415 - acc: 0.9889
# Epoch 191/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0458 - acc: 0.9874
# Epoch 192/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0429 - acc: 0.9885
# Epoch 193/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0408 - acc: 0.9895
# Epoch 194/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0408 - acc: 0.9898
# Epoch 195/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0424 - acc: 0.9894
# Epoch 196/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0457 - acc: 0.9877
# Epoch 197/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0431 - acc: 0.9883
# Epoch 198/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0452 - acc: 0.9886
# Epoch 199/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0469 - acc: 0.9875
# Epoch 200/200
# 6497/6497 [==============================] - 0s 4us/step - loss: 0.0458 - acc: 0.9889
# 6497/6497 [==============================] - 0s 11us/step
#
#  Accuracy: 0.9878

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint,EarlyStopping

import pandas as pd
import numpy
import os
import tensorflow as tf

# seed 값 설정
seed = 0
numpy.random.seed(seed)
tf.set_random_seed(seed)

df_pre = pd.read_csv('dataset/wine.csv', header=None)
df = df_pre.sample(frac=0.15)

dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

# 모델 저장 폴더 만들기
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"

# 모델 업데이트 및 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# 학습 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

model.fit(X, Y, validation_split=0.2, epochs=3500, batch_size=500, verbose=0, callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 00001: val_loss improved from inf to 0.48570, saving model to ./model/01-0.4857.hdf5
#
# Epoch 00002: val_loss improved from 0.48570 to 0.46075, saving model to ./model/02-0.4607.hdf5
#
# Epoch 00003: val_loss improved from 0.46075 to 0.43420, saving model to ./model/03-0.4342.hdf5
#
# Epoch 00004: val_loss improved from 0.43420 to 0.42063, saving model to ./model/04-0.4206.hdf5
#
# Epoch 00005: val_loss improved from 0.42063 to 0.40770, saving model to ./model/05-0.4077.hdf5
#
# Epoch 00006: val_loss improved from 0.40770 to 0.39446, saving model to ./model/06-0.3945.hdf5
#
# Epoch 00007: val_loss improved from 0.39446 to 0.38636, saving model to ./model/07-0.3864.hdf5
#
# Epoch 00008: val_loss improved from 0.38636 to 0.37932, saving model to ./model/08-0.3793.hdf5
#
# Epoch 00009: val_loss improved from 0.37932 to 0.37261, saving model to ./model/09-0.3726.hdf5
#
# Epoch 00010: val_loss improved from 0.37261 to 0.36562, saving model to ./model/10-0.3656.hdf5
#
# Epoch 00011: val_loss improved from 0.36562 to 0.35949, saving model to ./model/11-0.3595.hdf5
#
# Epoch 00012: val_loss improved from 0.35949 to 0.35433, saving model to ./model/12-0.3543.hdf5
#
# Epoch 00013: val_loss improved from 0.35433 to 0.34962, saving model to ./model/13-0.3496.hdf5
#
# Epoch 00014: val_loss improved from 0.34962 to 0.34484, saving model to ./model/14-0.3448.hdf5
#
# Epoch 00015: val_loss improved from 0.34484 to 0.33887, saving model to ./model/15-0.3389.hdf5
#
# Epoch 00016: val_loss improved from 0.33887 to 0.33349, saving model to ./model/16-0.3335.hdf5
#
# Epoch 00017: val_loss improved from 0.33349 to 0.32879, saving model to ./model/17-0.3288.hdf5
#
# Epoch 00018: val_loss improved from 0.32879 to 0.32504, saving model to ./model/18-0.3250.hdf5
#
# Epoch 00019: val_loss improved from 0.32504 to 0.32348, saving model to ./model/19-0.3235.hdf5
#
# Epoch 00020: val_loss improved from 0.32348 to 0.31964, saving model to ./model/20-0.3196.hdf5
#
# Epoch 00021: val_loss improved from 0.31964 to 0.31248, saving model to ./model/21-0.3125.hdf5
#
# Epoch 00022: val_loss improved from 0.31248 to 0.30776, saving model to ./model/22-0.3078.hdf5
#
# Epoch 00023: val_loss improved from 0.30776 to 0.30360, saving model to ./model/23-0.3036.hdf5
#
# Epoch 00024: val_loss improved from 0.30360 to 0.30043, saving model to ./model/24-0.3004.hdf5
#
# Epoch 00025: val_loss improved from 0.30043 to 0.29833, saving model to ./model/25-0.2983.hdf5
#
# Epoch 00026: val_loss improved from 0.29833 to 0.29356, saving model to ./model/26-0.2936.hdf5
#
# Epoch 00027: val_loss improved from 0.29356 to 0.28771, saving model to ./model/27-0.2877.hdf5
#
# Epoch 00028: val_loss improved from 0.28771 to 0.28375, saving model to ./model/28-0.2838.hdf5
#
# Epoch 00029: val_loss improved from 0.28375 to 0.27919, saving model to ./model/29-0.2792.hdf5
#
# Epoch 00030: val_loss improved from 0.27919 to 0.27654, saving model to ./model/30-0.2765.hdf5
#
# Epoch 00031: val_loss improved from 0.27654 to 0.27244, saving model to ./model/31-0.2724.hdf5
#
# Epoch 00032: val_loss improved from 0.27244 to 0.26756, saving model to ./model/32-0.2676.hdf5
#
# Epoch 00033: val_loss improved from 0.26756 to 0.26388, saving model to ./model/33-0.2639.hdf5
#
# Epoch 00034: val_loss improved from 0.26388 to 0.26048, saving model to ./model/34-0.2605.hdf5
#
# Epoch 00035: val_loss improved from 0.26048 to 0.25880, saving model to ./model/35-0.2588.hdf5
#
# Epoch 00036: val_loss improved from 0.25880 to 0.25559, saving model to ./model/36-0.2556.hdf5
#
# Epoch 00037: val_loss improved from 0.25559 to 0.25232, saving model to ./model/37-0.2523.hdf5
#
# Epoch 00038: val_loss improved from 0.25232 to 0.24974, saving model to ./model/38-0.2497.hdf5
#
# Epoch 00039: val_loss improved from 0.24974 to 0.24757, saving model to ./model/39-0.2476.hdf5
#
# Epoch 00040: val_loss improved from 0.24757 to 0.24563, saving model to ./model/40-0.2456.hdf5
#
# Epoch 00041: val_loss improved from 0.24563 to 0.24464, saving model to ./model/41-0.2446.hdf5
#
# Epoch 00042: val_loss improved from 0.24464 to 0.24245, saving model to ./model/42-0.2424.hdf5
#
# Epoch 00043: val_loss improved from 0.24245 to 0.24060, saving model to ./model/43-0.2406.hdf5
#
# Epoch 00044: val_loss improved from 0.24060 to 0.23862, saving model to ./model/44-0.2386.hdf5
#
# Epoch 00045: val_loss improved from 0.23862 to 0.23790, saving model to ./model/45-0.2379.hdf5
#
# Epoch 00046: val_loss improved from 0.23790 to 0.23772, saving model to ./model/46-0.2377.hdf5
#
# Epoch 00047: val_loss improved from 0.23772 to 0.23517, saving model to ./model/47-0.2352.hdf5
#
# Epoch 00048: val_loss improved from 0.23517 to 0.23242, saving model to ./model/48-0.2324.hdf5
#
# Epoch 00049: val_loss improved from 0.23242 to 0.23077, saving model to ./model/49-0.2308.hdf5
#
# Epoch 00050: val_loss improved from 0.23077 to 0.22996, saving model to ./model/50-0.2300.hdf5
#
# Epoch 00051: val_loss improved from 0.22996 to 0.22812, saving model to ./model/51-0.2281.hdf5
#
# Epoch 00052: val_loss improved from 0.22812 to 0.22684, saving model to ./model/52-0.2268.hdf5
#
# Epoch 00053: val_loss improved from 0.22684 to 0.22535, saving model to ./model/53-0.2253.hdf5
#
# Epoch 00054: val_loss improved from 0.22535 to 0.22452, saving model to ./model/54-0.2245.hdf5
#
# Epoch 00055: val_loss improved from 0.22452 to 0.22335, saving model to ./model/55-0.2233.hdf5
#
# Epoch 00056: val_loss improved from 0.22335 to 0.22145, saving model to ./model/56-0.2215.hdf5
#
# Epoch 00057: val_loss improved from 0.22145 to 0.21991, saving model to ./model/57-0.2199.hdf5
#
# Epoch 00058: val_loss improved from 0.21991 to 0.21837, saving model to ./model/58-0.2184.hdf5
#
# Epoch 00059: val_loss improved from 0.21837 to 0.21688, saving model to ./model/59-0.2169.hdf5
#
# Epoch 00060: val_loss improved from 0.21688 to 0.21659, saving model to ./model/60-0.2166.hdf5
#
# Epoch 00061: val_loss did not improve from 0.21659
#
# Epoch 00062: val_loss improved from 0.21659 to 0.21343, saving model to ./model/62-0.2134.hdf5
#
# Epoch 00063: val_loss improved from 0.21343 to 0.21097, saving model to ./model/63-0.2110.hdf5
#
# Epoch 00064: val_loss improved from 0.21097 to 0.20948, saving model to ./model/64-0.2095.hdf5
#
# Epoch 00065: val_loss improved from 0.20948 to 0.20938, saving model to ./model/65-0.2094.hdf5
#
# Epoch 00066: val_loss improved from 0.20938 to 0.20858, saving model to ./model/66-0.2086.hdf5
#
# Epoch 00067: val_loss improved from 0.20858 to 0.20590, saving model to ./model/67-0.2059.hdf5
#
# Epoch 00068: val_loss improved from 0.20590 to 0.20505, saving model to ./model/68-0.2050.hdf5
#
# Epoch 00069: val_loss improved from 0.20505 to 0.20371, saving model to ./model/69-0.2037.hdf5
#
# Epoch 00070: val_loss improved from 0.20371 to 0.20366, saving model to ./model/70-0.2037.hdf5
#
# Epoch 00071: val_loss did not improve from 0.20366
#
# Epoch 00072: val_loss improved from 0.20366 to 0.20204, saving model to ./model/72-0.2020.hdf5
#
# Epoch 00073: val_loss improved from 0.20204 to 0.19926, saving model to ./model/73-0.1993.hdf5
#
# Epoch 00074: val_loss improved from 0.19926 to 0.19813, saving model to ./model/74-0.1981.hdf5
#
# Epoch 00075: val_loss improved from 0.19813 to 0.19797, saving model to ./model/75-0.1980.hdf5
#
# Epoch 00076: val_loss did not improve from 0.19797
#
# Epoch 00077: val_loss improved from 0.19797 to 0.19741, saving model to ./model/77-0.1974.hdf5
#
# Epoch 00078: val_loss improved from 0.19741 to 0.19570, saving model to ./model/78-0.1957.hdf5
#
# Epoch 00079: val_loss improved from 0.19570 to 0.19289, saving model to ./model/79-0.1929.hdf5
#
# Epoch 00080: val_loss improved from 0.19289 to 0.19151, saving model to ./model/80-0.1915.hdf5
#
# Epoch 00081: val_loss did not improve from 0.19151
#
# Epoch 00082: val_loss did not improve from 0.19151
#
# Epoch 00083: val_loss improved from 0.19151 to 0.19142, saving model to ./model/83-0.1914.hdf5
#
# Epoch 00084: val_loss improved from 0.19142 to 0.18843, saving model to ./model/84-0.1884.hdf5
#
# Epoch 00085: val_loss improved from 0.18843 to 0.18755, saving model to ./model/85-0.1876.hdf5
#
# Epoch 00086: val_loss improved from 0.18755 to 0.18732, saving model to ./model/86-0.1873.hdf5
#
# Epoch 00087: val_loss did not improve from 0.18732
#
# Epoch 00088: val_loss did not improve from 0.18732
#
# Epoch 00089: val_loss improved from 0.18732 to 0.18662, saving model to ./model/89-0.1866.hdf5
#
# Epoch 00090: val_loss improved from 0.18662 to 0.18396, saving model to ./model/90-0.1840.hdf5
#
# Epoch 00091: val_loss improved from 0.18396 to 0.18268, saving model to ./model/91-0.1827.hdf5
#
# Epoch 00092: val_loss did not improve from 0.18268
#
# Epoch 00093: val_loss did not improve from 0.18268
#
# Epoch 00094: val_loss did not improve from 0.18268
#
# Epoch 00095: val_loss improved from 0.18268 to 0.18173, saving model to ./model/95-0.1817.hdf5
#
# Epoch 00096: val_loss improved from 0.18173 to 0.18084, saving model to ./model/96-0.1808.hdf5
#
# Epoch 00097: val_loss improved from 0.18084 to 0.18042, saving model to ./model/97-0.1804.hdf5
#
# Epoch 00098: val_loss improved from 0.18042 to 0.17950, saving model to ./model/98-0.1795.hdf5
# Epoch 00099: val_loss improved from 0.17950 to 0.17924, saving model to ./model/99-0.1792.hdf5
#
# Epoch 00100: val_loss improved from 0.17924 to 0.17763, saving model to ./model/100-0.1776.hdf5
#
# Epoch 00101: val_loss improved from 0.17763 to 0.17622, saving model to ./model/101-0.1762.hdf5
#
# Epoch 00102: val_loss improved from 0.17622 to 0.17445, saving model to ./model/102-0.1744.hdf5
#
# Epoch 00103: val_loss improved from 0.17445 to 0.17382, saving model to ./model/103-0.1738.hdf5
#
# Epoch 00104: val_loss did not improve from 0.17382
#
# Epoch 00105: val_loss did not improve from 0.17382
#
# Epoch 00106: val_loss did not improve from 0.17382
#
# Epoch 00107: val_loss improved from 0.17382 to 0.17026, saving model to ./model/107-0.1703.hdf5
#
# Epoch 00108: val_loss improved from 0.17026 to 0.16948, saving model to ./model/108-0.1695.hdf5
#
# Epoch 00109: val_loss did not improve from 0.16948
#
# Epoch 00110: val_loss did not improve from 0.16948
#
# Epoch 00111: val_loss did not improve from 0.16948
#
# Epoch 00112: val_loss improved from 0.16948 to 0.16690, saving model to ./model/112-0.1669.hdf5
#
# Epoch 00113: val_loss improved from 0.16690 to 0.16630, saving model to ./model/113-0.1663.hdf5
#
# Epoch 00114: val_loss did not improve from 0.16630
#
# Epoch 00115: val_loss did not improve from 0.16630
#
# Epoch 00116: val_loss did not improve from 0.16630
#
# Epoch 00117: val_loss improved from 0.16630 to 0.16486, saving model to ./model/117-0.1649.hdf5
#
# Epoch 00118: val_loss improved from 0.16486 to 0.16447, saving model to ./model/118-0.1645.hdf5
#
# Epoch 00119: val_loss did not improve from 0.16447
#
# Epoch 00120: val_loss did not improve from 0.16447
#
# Epoch 00121: val_loss improved from 0.16447 to 0.16403, saving model to ./model/121-0.1640.hdf5
#
# Epoch 00122: val_loss improved from 0.16403 to 0.16044, saving model to ./model/122-0.1604.hdf5
#
# Epoch 00123: val_loss did not improve from 0.16044
#
# Epoch 00124: val_loss did not improve from 0.16044
#
# Epoch 00125: val_loss did not improve from 0.16044
#
# Epoch 00126: val_loss did not improve from 0.16044
#
# Epoch 00127: val_loss improved from 0.16044 to 0.15826, saving model to ./model/127-0.1583.hdf5
#
# Epoch 00128: val_loss did not improve from 0.15826
#
# Epoch 00129: val_loss did not improve from 0.15826
#
# Epoch 00130: val_loss did not improve from 0.15826
#
# Epoch 00131: val_loss did not improve from 0.15826
#
# Epoch 00132: val_loss improved from 0.15826 to 0.15613, saving model to ./model/132-0.1561.hdf5
#
# Epoch 00133: val_loss improved from 0.15613 to 0.15535, saving model to ./model/133-0.1554.hdf5
#
# Epoch 00134: val_loss did not improve from 0.15535
#
# Epoch 00135: val_loss did not improve from 0.15535
#
# Epoch 00136: val_loss improved from 0.15535 to 0.15461, saving model to ./model/136-0.1546.hdf5
#
# Epoch 00137: val_loss improved from 0.15461 to 0.15367, saving model to ./model/137-0.1537.hdf5
#
# Epoch 00138: val_loss did not improve from 0.15367
#
# Epoch 00139: val_loss did not improve from 0.15367
#
# Epoch 00140: val_loss improved from 0.15367 to 0.15241, saving model to ./model/140-0.1524.hdf5
#
# Epoch 00141: val_loss improved from 0.15241 to 0.15147, saving model to ./model/141-0.1515.hdf5
#
# Epoch 00142: val_loss did not improve from 0.15147
#
# Epoch 00143: val_loss did not improve from 0.15147
#
# Epoch 00144: val_loss did not improve from 0.15147
#
# Epoch 00145: val_loss improved from 0.15147 to 0.14927, saving model to ./model/145-0.1493.hdf5
#
# Epoch 00146: val_loss improved from 0.14927 to 0.14898, saving model to ./model/146-0.1490.hdf5
#
# Epoch 00147: val_loss did not improve from 0.14898
#
# Epoch 00148: val_loss did not improve from 0.14898
#
# Epoch 00149: val_loss did not improve from 0.14898
#
# Epoch 00150: val_loss did not improve from 0.14898
#
# Epoch 00151: val_loss did not improve from 0.14898
#
# Epoch 00152: val_loss did not improve from 0.14898
#
# Epoch 00153: val_loss did not improve from 0.14898
#
# Epoch 00154: val_loss improved from 0.14898 to 0.14601, saving model to ./model/154-0.1460.hdf5
#
# Epoch 00155: val_loss improved from 0.14601 to 0.14420, saving model to ./model/155-0.1442.hdf5
#
# Epoch 00156: val_loss did not improve from 0.14420
#
# Epoch 00157: val_loss did not improve from 0.14420
#
# Epoch 00158: val_loss did not improve from 0.14420
#
# Epoch 00159: val_loss did not improve from 0.14420
#
# Epoch 00160: val_loss improved from 0.14420 to 0.14334, saving model to ./model/160-0.1433.hdf5
#
# Epoch 00161: val_loss did not improve from 0.14334
#
# Epoch 00162: val_loss did not improve from 0.14334
#
# Epoch 00163: val_loss improved from 0.14334 to 0.14269, saving model to ./model/163-0.1427.hdf5
#
# Epoch 00164: val_loss improved from 0.14269 to 0.14063, saving model to ./model/164-0.1406.hdf5
#
# Epoch 00165: val_loss did not improve from 0.14063
#
# Epoch 00166: val_loss did not improve from 0.14063
#
# Epoch 00167: val_loss did not improve from 0.14063
#
# Epoch 00168: val_loss improved from 0.14063 to 0.13933, saving model to ./model/168-0.1393.hdf5
#
# Epoch 00169: val_loss improved from 0.13933 to 0.13839, saving model to ./model/169-0.1384.hdf5
#
# Epoch 00170: val_loss did not improve from 0.13839
#
# Epoch 00171: val_loss did not improve from 0.13839
#
# Epoch 00172: val_loss did not improve from 0.13839
#
# Epoch 00173: val_loss did not improve from 0.13839
#
# Epoch 00174: val_loss did not improve from 0.13839
#
# Epoch 00175: val_loss did not improve from 0.13839
#
# Epoch 00176: val_loss improved from 0.13839 to 0.13547, saving model to ./model/176-0.1355.hdf5
#
# Epoch 00177: val_loss did not improve from 0.13547
#
# Epoch 00178: val_loss did not improve from 0.13547
#
# Epoch 00179: val_loss did not improve from 0.13547
#
# Epoch 00180: val_loss did not improve from 0.13547
#
# Epoch 00181: val_loss improved from 0.13547 to 0.13343, saving model to ./model/181-0.1334.hdf5
#
# Epoch 00182: val_loss did not improve from 0.13343
#
# Epoch 00183: val_loss did not improve from 0.13343
#
# Epoch 00184: val_loss did not improve from 0.13343
#
# Epoch 00185: val_loss did not improve from 0.13343
#
# Epoch 00186: val_loss improved from 0.13343 to 0.13261, saving model to ./model/186-0.1326.hdf5
#
# Epoch 00187: val_loss did not improve from 0.13261
#
# Epoch 00188: val_loss did not improve from 0.13261
#
# Epoch 00189: val_loss did not improve from 0.13261
#
# Epoch 00190: val_loss improved from 0.13261 to 0.13038, saving model to ./model/190-0.1304.hdf5
#
# Epoch 00191: val_loss did not improve from 0.13038
#
# Epoch 00192: val_loss did not improve from 0.13038
#
# Epoch 00193: val_loss did not improve from 0.13038
#
# Epoch 00194: val_loss improved from 0.13038 to 0.13008, saving model to ./model/194-0.1301.hdf5
#
# Epoch 00195: val_loss did not improve from 0.13008
#
# Epoch 00196: val_loss did not improve from 0.13008
#
# Epoch 00197: val_loss improved from 0.13008 to 0.12962, saving model to ./model/197-0.1296.hdf5
#
# Epoch 00198: val_loss improved from 0.12962 to 0.12739, saving model to ./model/198-0.1274.hdf5
#
# Epoch 00199: val_loss did not improve from 0.12739
#
# Epoch 00200: val_loss did not improve from 0.12739
#
# Epoch 00201: val_loss did not improve from 0.12739
#
# Epoch 00202: val_loss improved from 0.12739 to 0.12652, saving model to ./model/202-0.1265.hdf5
#
# Epoch 00203: val_loss did not improve from 0.12652
#
# Epoch 00204: val_loss did not improve from 0.12652
#
# Epoch 00205: val_loss did not improve from 0.12652
#
# Epoch 00206: val_loss improved from 0.12652 to 0.12588, saving model to ./model/206-0.1259.hdf5
#
# Epoch 00207: val_loss did not improve from 0.12588
#
# Epoch 00208: val_loss did not improve from 0.12588
#
# Epoch 00209: val_loss did not improve from 0.12588
#
# Epoch 00210: val_loss did not improve from 0.12588
#
# Epoch 00211: val_loss improved from 0.12588 to 0.12505, saving model to ./model/211-0.1251.hdf5
#
# Epoch 00212: val_loss did not improve from 0.12505
#
# Epoch 00213: val_loss did not improve from 0.12505
#
# Epoch 00214: val_loss did not improve from 0.12505
#
# Epoch 00215: val_loss improved from 0.12505 to 0.12367, saving model to ./model/215-0.1237.hdf5
#
# Epoch 00216: val_loss did not improve from 0.12367
#
# Epoch 00217: val_loss did not improve from 0.12367
#
# Epoch 00218: val_loss did not improve from 0.12367
#
# Epoch 00219: val_loss did not improve from 0.12367
#
# Epoch 00220: val_loss did not improve from 0.12367
#
# Epoch 00221: val_loss did not improve from 0.12367
#
# Epoch 00222: val_loss did not improve from 0.12367
#
# Epoch 00223: val_loss did not improve from 0.12367
#
# Epoch 00224: val_loss did not improve from 0.12367
#
# Epoch 00225: val_loss did not improve from 0.12367
#
# Epoch 00226: val_loss did not improve from 0.12367
#
# Epoch 00227: val_loss improved from 0.12367 to 0.12207, saving model to ./model/227-0.1221.hdf5
#
# Epoch 00228: val_loss did not improve from 0.12207
#
# Epoch 00229: val_loss did not improve from 0.12207
#
# Epoch 00230: val_loss improved from 0.12207 to 0.12088, saving model to ./model/230-0.1209.hdf5
#
# Epoch 00231: val_loss improved from 0.12088 to 0.11945, saving model to ./model/231-0.1195.hdf5
#
# Epoch 00232: val_loss did not improve from 0.11945
#
# Epoch 00233: val_loss did not improve from 0.11945
#
# Epoch 00234: val_loss improved from 0.11945 to 0.11867, saving model to ./model/234-0.1187.hdf5
#
# Epoch 00235: val_loss did not improve from 0.11867
#
# Epoch 00236: val_loss did not improve from 0.11867
#
# Epoch 00237: val_loss did not improve from 0.11867
#
# Epoch 00238: val_loss improved from 0.11867 to 0.11793, saving model to ./model/238-0.1179.hdf5
# Epoch 00239: val_loss did not improve from 0.11793
#
# Epoch 00240: val_loss did not improve from 0.11793
#
# Epoch 00241: val_loss did not improve from 0.11793
#
# Epoch 00242: val_loss improved from 0.11793 to 0.11574, saving model to ./model/242-0.1157.hdf5
#
# Epoch 00243: val_loss did not improve from 0.11574
#
# Epoch 00244: val_loss did not improve from 0.11574
#
# Epoch 00245: val_loss did not improve from 0.11574
#
# Epoch 00246: val_loss did not improve from 0.11574
#
# Epoch 00247: val_loss did not improve from 0.11574
#
# Epoch 00248: val_loss did not improve from 0.11574
#
# Epoch 00249: val_loss improved from 0.11574 to 0.11544, saving model to ./model/249-0.1154.hdf5
#
# Epoch 00250: val_loss improved from 0.11544 to 0.11349, saving model to ./model/250-0.1135.hdf5
#
# Epoch 00251: val_loss did not improve from 0.11349
#
# Epoch 00252: val_loss did not improve from 0.11349
#
# Epoch 00253: val_loss did not improve from 0.11349
#
# Epoch 00254: val_loss improved from 0.11349 to 0.11336, saving model to ./model/254-0.1134.hdf5
#
# Epoch 00255: val_loss did not improve from 0.11336
#
# Epoch 00256: val_loss did not improve from 0.11336
#
# Epoch 00257: val_loss did not improve from 0.11336
#
# Epoch 00258: val_loss improved from 0.11336 to 0.11257, saving model to ./model/258-0.1126.hdf5
#
# Epoch 00259: val_loss did not improve from 0.11257
#
# Epoch 00260: val_loss did not improve from 0.11257
#
# Epoch 00261: val_loss improved from 0.11257 to 0.11243, saving model to ./model/261-0.1124.hdf5
#
# Epoch 00262: val_loss improved from 0.11243 to 0.11142, saving model to ./model/262-0.1114.hdf5
#
# Epoch 00263: val_loss did not improve from 0.11142
#
# Epoch 00264: val_loss did not improve from 0.11142
#
# Epoch 00265: val_loss did not improve from 0.11142
#
# Epoch 00266: val_loss improved from 0.11142 to 0.10848, saving model to ./model/266-0.1085.hdf5
#
# Epoch 00267: val_loss did not improve from 0.10848
#
# Epoch 00268: val_loss did not improve from 0.10848
#
# Epoch 00269: val_loss did not improve from 0.10848
#
# Epoch 00270: val_loss did not improve from 0.10848
#
# Epoch 00271: val_loss did not improve from 0.10848
#
# Epoch 00272: val_loss did not improve from 0.10848
#
# Epoch 00273: val_loss did not improve from 0.10848
#
# Epoch 00274: val_loss did not improve from 0.10848
#
# Epoch 00275: val_loss did not improve from 0.10848
#
# Epoch 00276: val_loss did not improve from 0.10848
#
# Epoch 00277: val_loss did not improve from 0.10848
#
# Epoch 00278: val_loss did not improve from 0.10848
#
# Epoch 00279: val_loss improved from 0.10848 to 0.10806, saving model to ./model/279-0.1081.hdf5
#
# Epoch 00280: val_loss did not improve from 0.10806
#
# Epoch 00281: val_loss did not improve from 0.10806
#
# Epoch 00282: val_loss did not improve from 0.10806
#
# Epoch 00283: val_loss did not improve from 0.10806
#
# Epoch 00284: val_loss did not improve from 0.10806
#
# Epoch 00285: val_loss did not improve from 0.10806
#
# Epoch 00286: val_loss did not improve from 0.10806
#
# Epoch 00287: val_loss improved from 0.10806 to 0.10592, saving model to ./model/287-0.1059.hdf5
#
# Epoch 00288: val_loss did not improve from 0.10592
#
# Epoch 00289: val_loss did not improve from 0.10592
#
# Epoch 00290: val_loss did not improve from 0.10592
#
# Epoch 00291: val_loss did not improve from 0.10592
#
# Epoch 00292: val_loss improved from 0.10592 to 0.10427, saving model to ./model/292-0.1043.hdf5
#
# Epoch 00293: val_loss did not improve from 0.10427
#
# Epoch 00294: val_loss did not improve from 0.10427
#
# Epoch 00295: val_loss did not improve from 0.10427
#
# Epoch 00296: val_loss did not improve from 0.10427
#
# Epoch 00297: val_loss did not improve from 0.10427
#
# Epoch 00298: val_loss did not improve from 0.10427
#
# Epoch 00299: val_loss improved from 0.10427 to 0.10039, saving model to ./model/299-0.1004.hdf5
#
# Epoch 00300: val_loss did not improve from 0.10039
#
# Epoch 00301: val_loss did not improve from 0.10039
#
# Epoch 00302: val_loss did not improve from 0.10039
#
# Epoch 00303: val_loss improved from 0.10039 to 0.10028, saving model to ./model/303-0.1003.hdf5
#
# Epoch 00304: val_loss did not improve from 0.10028
#
# Epoch 00305: val_loss did not improve from 0.10028
#
# Epoch 00306: val_loss improved from 0.10028 to 0.09902, saving model to ./model/306-0.0990.hdf5
#
# Epoch 00307: val_loss did not improve from 0.09902
#
# Epoch 00308: val_loss did not improve from 0.09902
#
# Epoch 00309: val_loss did not improve from 0.09902
#
# Epoch 00310: val_loss improved from 0.09902 to 0.09885, saving model to ./model/310-0.0988.hdf5
#
# Epoch 00311: val_loss did not improve from 0.09885
#
# Epoch 00312: val_loss did not improve from 0.09885
#
# Epoch 00313: val_loss did not improve from 0.09885
#
# Epoch 00314: val_loss did not improve from 0.09885
#
# Epoch 00315: val_loss did not improve from 0.09885
#
# Epoch 00316: val_loss did not improve from 0.09885
#
# Epoch 00317: val_loss did not improve from 0.09885
#
# Epoch 00318: val_loss did not improve from 0.09885
#
# Epoch 00319: val_loss did not improve from 0.09885
#
# Epoch 00320: val_loss improved from 0.09885 to 0.09757, saving model to ./model/320-0.0976.hdf5
#
# Epoch 00321: val_loss did not improve from 0.09757
#
# Epoch 00322: val_loss did not improve from 0.09757
#
# Epoch 00323: val_loss improved from 0.09757 to 0.09575, saving model to ./model/323-0.0958.hdf5
#
# Epoch 00324: val_loss did not improve from 0.09575
#
# Epoch 00325: val_loss did not improve from 0.09575
#
# Epoch 00326: val_loss did not improve from 0.09575
#
# Epoch 00327: val_loss did not improve from 0.09575
#
# Epoch 00328: val_loss did not improve from 0.09575
#
# Epoch 00329: val_loss did not improve from 0.09575
#
# Epoch 00330: val_loss improved from 0.09575 to 0.09400, saving model to ./model/330-0.0940.hdf5
#
# Epoch 00331: val_loss did not improve from 0.09400
#
# Epoch 00332: val_loss did not improve from 0.09400
#
# Epoch 00333: val_loss did not improve from 0.09400
#
# Epoch 00334: val_loss improved from 0.09400 to 0.09365, saving model to ./model/334-0.0936.hdf5
#
# Epoch 00335: val_loss did not improve from 0.09365
#
# Epoch 00336: val_loss did not improve from 0.09365
#
# Epoch 00337: val_loss improved from 0.09365 to 0.09158, saving model to ./model/337-0.0916.hdf5
#
# Epoch 00338: val_loss did not improve from 0.09158
#
# Epoch 00339: val_loss did not improve from 0.09158
#
# Epoch 00340: val_loss did not improve from 0.09158
#
# Epoch 00341: val_loss did not improve from 0.09158
#
# Epoch 00342: val_loss did not improve from 0.09158
#
# Epoch 00343: val_loss did not improve from 0.09158
#
# Epoch 00344: val_loss did not improve from 0.09158
#
# Epoch 00345: val_loss did not improve from 0.09158
#
# Epoch 00346: val_loss did not improve from 0.09158
#
# Epoch 00347: val_loss did not improve from 0.09158
#
# Epoch 00348: val_loss did not improve from 0.09158
#
# Epoch 00349: val_loss did not improve from 0.09158
#
# Epoch 00350: val_loss did not improve from 0.09158
#
# Epoch 00351: val_loss did not improve from 0.09158
#
# Epoch 00352: val_loss did not improve from 0.09158
#
# Epoch 00353: val_loss did not improve from 0.09158
#
# Epoch 00354: val_loss did not improve from 0.09158
#
# Epoch 00355: val_loss did not improve from 0.09158
#
# Epoch 00356: val_loss improved from 0.09158 to 0.09107, saving model to ./model/356-0.0911.hdf5
#
# Epoch 00357: val_loss did not improve from 0.09107
#
# Epoch 00358: val_loss did not improve from 0.09107
#
# Epoch 00359: val_loss did not improve from 0.09107
#
# Epoch 00360: val_loss did not improve from 0.09107
#
# Epoch 00361: val_loss did not improve from 0.09107
#
# Epoch 00362: val_loss improved from 0.09107 to 0.08945, saving model to ./model/362-0.0895.hdf5
#
# Epoch 00363: val_loss did not improve from 0.08945
#
# Epoch 00364: val_loss did not improve from 0.08945
#
# Epoch 00365: val_loss did not improve from 0.08945
#
# Epoch 00366: val_loss did not improve from 0.08945
#
# Epoch 00367: val_loss did not improve from 0.08945
#
# Epoch 00368: val_loss did not improve from 0.08945
#
# Epoch 00369: val_loss did not improve from 0.08945
#
# Epoch 00370: val_loss improved from 0.08945 to 0.08654, saving model to ./model/370-0.0865.hdf5
#
# Epoch 00371: val_loss did not improve from 0.08654
#
# Epoch 00372: val_loss did not improve from 0.08654
#
# Epoch 00373: val_loss did not improve from 0.08654
#
# Epoch 00374: val_loss improved from 0.08654 to 0.08532, saving model to ./model/374-0.0853.hdf5
#
# Epoch 00375: val_loss did not improve from 0.08532
# Epoch 00376: val_loss did not improve from 0.08532
#
# Epoch 00377: val_loss did not improve from 0.08532
#
# Epoch 00378: val_loss improved from 0.08532 to 0.08498, saving model to ./model/378-0.0850.hdf5
#
# Epoch 00379: val_loss did not improve from 0.08498
#
# Epoch 00380: val_loss did not improve from 0.08498
#
# Epoch 00381: val_loss did not improve from 0.08498
#
# Epoch 00382: val_loss improved from 0.08498 to 0.08484, saving model to ./model/382-0.0848.hdf5
#
# Epoch 00383: val_loss did not improve from 0.08484
#
# Epoch 00384: val_loss did not improve from 0.08484
#
# Epoch 00385: val_loss did not improve from 0.08484
#
# Epoch 00386: val_loss improved from 0.08484 to 0.08374, saving model to ./model/386-0.0837.hdf5
#
# Epoch 00387: val_loss did not improve from 0.08374
#
# Epoch 00388: val_loss did not improve from 0.08374
#
# Epoch 00389: val_loss did not improve from 0.08374
#
# Epoch 00390: val_loss improved from 0.08374 to 0.08314, saving model to ./model/390-0.0831.hdf5
#
# Epoch 00391: val_loss did not improve from 0.08314
#
# Epoch 00392: val_loss did not improve from 0.08314
#
# Epoch 00393: val_loss did not improve from 0.08314
#
# Epoch 00394: val_loss did not improve from 0.08314
#
# Epoch 00395: val_loss did not improve from 0.08314
#
# Epoch 00396: val_loss did not improve from 0.08314
#
# Epoch 00397: val_loss improved from 0.08314 to 0.08102, saving model to ./model/397-0.0810.hdf5
#
# Epoch 00398: val_loss did not improve from 0.08102
#
# Epoch 00399: val_loss did not improve from 0.08102
#
# Epoch 00400: val_loss did not improve from 0.08102
#
# Epoch 00401: val_loss did not improve from 0.08102
#
# Epoch 00402: val_loss did not improve from 0.08102
#
# Epoch 00403: val_loss improved from 0.08102 to 0.08064, saving model to ./model/403-0.0806.hdf5
#
# Epoch 00404: val_loss did not improve from 0.08064
#
# Epoch 00405: val_loss did not improve from 0.08064
#
# Epoch 00406: val_loss did not improve from 0.08064
#
# Epoch 00407: val_loss improved from 0.08064 to 0.07976, saving model to ./model/407-0.0798.hdf5
#
# Epoch 00408: val_loss did not improve from 0.07976
#
# Epoch 00409: val_loss did not improve from 0.07976
#
# Epoch 00410: val_loss did not improve from 0.07976
#
# Epoch 00411: val_loss did not improve from 0.07976
#
# Epoch 00412: val_loss did not improve from 0.07976
#
# Epoch 00413: val_loss did not improve from 0.07976
#
# Epoch 00414: val_loss did not improve from 0.07976
#
# Epoch 00415: val_loss did not improve from 0.07976
#
# Epoch 00416: val_loss did not improve from 0.07976
#
# Epoch 00417: val_loss did not improve from 0.07976
#
# Epoch 00418: val_loss improved from 0.07976 to 0.07902, saving model to ./model/418-0.0790.hdf5
#
# Epoch 00419: val_loss did not improve from 0.07902
#
# Epoch 00420: val_loss did not improve from 0.07902
#
# Epoch 00421: val_loss improved from 0.07902 to 0.07683, saving model to ./model/421-0.0768.hdf5
#
# Epoch 00422: val_loss did not improve from 0.07683
#
# Epoch 00423: val_loss did not improve from 0.07683
#
# Epoch 00424: val_loss did not improve from 0.07683
#
# Epoch 00425: val_loss improved from 0.07683 to 0.07598, saving model to ./model/425-0.0760.hdf5
#
# Epoch 00426: val_loss did not improve from 0.07598
#
# Epoch 00427: val_loss did not improve from 0.07598
#
# Epoch 00428: val_loss did not improve from 0.07598
#
# Epoch 00429: val_loss improved from 0.07598 to 0.07572, saving model to ./model/429-0.0757.hdf5
#
# Epoch 00430: val_loss did not improve from 0.07572
#
# Epoch 00431: val_loss did not improve from 0.07572
#
# Epoch 00432: val_loss improved from 0.07572 to 0.07536, saving model to ./model/432-0.0754.hdf5
#
# Epoch 00433: val_loss did not improve from 0.07536
#
# Epoch 00434: val_loss did not improve from 0.07536
#
# Epoch 00435: val_loss did not improve from 0.07536
#
# Epoch 00436: val_loss did not improve from 0.07536
#
# Epoch 00437: val_loss did not improve from 0.07536
#
# Epoch 00438: val_loss did not improve from 0.07536
#
# Epoch 00439: val_loss improved from 0.07536 to 0.07476, saving model to ./model/439-0.0748.hdf5
#
# Epoch 00440: val_loss did not improve from 0.07476
#
# Epoch 00441: val_loss did not improve from 0.07476
#
# Epoch 00442: val_loss did not improve from 0.07476
#
# Epoch 00443: val_loss did not improve from 0.07476
#
# Epoch 00444: val_loss did not improve from 0.07476
#
# Epoch 00445: val_loss did not improve from 0.07476
#
# Epoch 00446: val_loss did not improve from 0.07476
#
# Epoch 00447: val_loss did not improve from 0.07476
#
# Epoch 00448: val_loss improved from 0.07476 to 0.07290, saving model to ./model/448-0.0729.hdf5
#
# Epoch 00449: val_loss did not improve from 0.07290
#
# Epoch 00450: val_loss did not improve from 0.07290
#
# Epoch 00451: val_loss did not improve from 0.07290
#
# Epoch 00452: val_loss did not improve from 0.07290
#
# Epoch 00453: val_loss did not improve from 0.07290
#
# Epoch 00454: val_loss did not improve from 0.07290
#
# Epoch 00455: val_loss did not improve from 0.07290
#
# Epoch 00456: val_loss did not improve from 0.07290
#
# Epoch 00457: val_loss did not improve from 0.07290
#
# Epoch 00458: val_loss did not improve from 0.07290
#
# Epoch 00459: val_loss improved from 0.07290 to 0.07174, saving model to ./model/459-0.0717.hdf5
#
# Epoch 00460: val_loss did not improve from 0.07174
#
# Epoch 00461: val_loss did not improve from 0.07174
#
# Epoch 00462: val_loss did not improve from 0.07174
#
# Epoch 00463: val_loss did not improve from 0.07174
#
# Epoch 00464: val_loss did not improve from 0.07174
#
# Epoch 00465: val_loss did not improve from 0.07174
#
# Epoch 00466: val_loss did not improve from 0.07174
#
# Epoch 00467: val_loss did not improve from 0.07174
#
# Epoch 00468: val_loss did not improve from 0.07174
#
# Epoch 00469: val_loss did not improve from 0.07174
#
# Epoch 00470: val_loss did not improve from 0.07174
#
# Epoch 00471: val_loss did not improve from 0.07174
#
# Epoch 00472: val_loss did not improve from 0.07174
#
# Epoch 00473: val_loss did not improve from 0.07174
#
# Epoch 00474: val_loss did not improve from 0.07174
#
# Epoch 00475: val_loss improved from 0.07174 to 0.07035, saving model to ./model/475-0.0704.hdf5
#
# Epoch 00476: val_loss did not improve from 0.07035
#
# Epoch 00477: val_loss did not improve from 0.07035
#
# Epoch 00478: val_loss did not improve from 0.07035
#
# Epoch 00479: val_loss did not improve from 0.07035
#
# Epoch 00480: val_loss did not improve from 0.07035
#
# Epoch 00481: val_loss did not improve from 0.07035
#
# Epoch 00482: val_loss did not improve from 0.07035
#
# Epoch 00483: val_loss did not improve from 0.07035
#
# Epoch 00484: val_loss did not improve from 0.07035
#
# Epoch 00485: val_loss did not improve from 0.07035
#
# Epoch 00486: val_loss did not improve from 0.07035
#
# Epoch 00487: val_loss did not improve from 0.07035
#
# Epoch 00488: val_loss improved from 0.07035 to 0.07031, saving model to ./model/488-0.0703.hdf5
#
# Epoch 00489: val_loss did not improve from 0.07031
#
# Epoch 00490: val_loss did not improve from 0.07031
#
# Epoch 00491: val_loss did not improve from 0.07031
#
# Epoch 00492: val_loss improved from 0.07031 to 0.07014, saving model to ./model/492-0.0701.hdf5
#
# Epoch 00493: val_loss did not improve from 0.07014
#
# Epoch 00494: val_loss did not improve from 0.07014
#
# Epoch 00495: val_loss improved from 0.07014 to 0.06991, saving model to ./model/495-0.0699.hdf5
#
# Epoch 00496: val_loss did not improve from 0.06991
#
# Epoch 00497: val_loss did not improve from 0.06991
#
# Epoch 00498: val_loss improved from 0.06991 to 0.06804, saving model to ./model/498-0.0680.hdf5
#
# Epoch 00499: val_loss did not improve from 0.06804
#
# Epoch 00500: val_loss did not improve from 0.06804
#
# Epoch 00501: val_loss did not improve from 0.06804
#
# Epoch 00502: val_loss improved from 0.06804 to 0.06768, saving model to ./model/502-0.0677.hdf5
#
# Epoch 00503: val_loss did not improve from 0.06768
#
# Epoch 00504: val_loss did not improve from 0.06768
#
# Epoch 00505: val_loss did not improve from 0.06768
#
# Epoch 00506: val_loss did not improve from 0.06768
#
# Epoch 00507: val_loss did not improve from 0.06768
#
# Epoch 00508: val_loss did not improve from 0.06768
#
# Epoch 00509: val_loss improved from 0.06768 to 0.06740, saving model to ./model/509-0.0674.hdf5
#
# Epoch 00510: val_loss did not improve from 0.06740
#
# Epoch 00511: val_loss did not improve from 0.06740
#
# Epoch 00512: val_loss did not improve from 0.06740
#
# Epoch 00513: val_loss improved from 0.06740 to 0.06636, saving model to ./model/513-0.0664.hdf5
#
# Epoch 00514: val_loss did not improve from 0.06636
#
# Epoch 00515: val_loss did not improve from 0.06636
#
# Epoch 00516: val_loss improved from 0.06636 to 0.06604, saving model to ./model/516-0.0660.hdf5
#
# Epoch 00517: val_loss did not improve from 0.06604
#
# Epoch 00518: val_loss did not improve from 0.06604
#
# Epoch 00519: val_loss did not improve from 0.06604
#
# Epoch 00520: val_loss did not improve from 0.06604
# Epoch 00521: val_loss did not improve from 0.06604
#
# Epoch 00522: val_loss did not improve from 0.06604
#
# Epoch 00523: val_loss improved from 0.06604 to 0.06389, saving model to ./model/523-0.0639.hdf5
#
# Epoch 00524: val_loss did not improve from 0.06389
#
# Epoch 00525: val_loss did not improve from 0.06389
#
# Epoch 00526: val_loss did not improve from 0.06389
#
# Epoch 00527: val_loss improved from 0.06389 to 0.06344, saving model to ./model/527-0.0634.hdf5
#
# Epoch 00528: val_loss did not improve from 0.06344
#
# Epoch 00529: val_loss did not improve from 0.06344
#
# Epoch 00530: val_loss improved from 0.06344 to 0.06295, saving model to ./model/530-0.0630.hdf5
#
# Epoch 00531: val_loss did not improve from 0.06295
#
# Epoch 00532: val_loss did not improve from 0.06295
#
# Epoch 00533: val_loss did not improve from 0.06295
#
# Epoch 00534: val_loss did not improve from 0.06295
#
# Epoch 00535: val_loss did not improve from 0.06295
#
# Epoch 00536: val_loss did not improve from 0.06295
#
# Epoch 00537: val_loss did not improve from 0.06295
#
# Epoch 00538: val_loss did not improve from 0.06295
#
# Epoch 00539: val_loss did not improve from 0.06295
#
# Epoch 00540: val_loss did not improve from 0.06295
#
# Epoch 00541: val_loss did not improve from 0.06295
#
# Epoch 00542: val_loss did not improve from 0.06295
#
# Epoch 00543: val_loss improved from 0.06295 to 0.06194, saving model to ./model/543-0.0619.hdf5
#
# Epoch 00544: val_loss did not improve from 0.06194
#
# Epoch 00545: val_loss did not improve from 0.06194
#
# Epoch 00546: val_loss did not improve from 0.06194
#
# Epoch 00547: val_loss improved from 0.06194 to 0.06192, saving model to ./model/547-0.0619.hdf5
#
# Epoch 00548: val_loss did not improve from 0.06192
#
# Epoch 00549: val_loss did not improve from 0.06192
#
# Epoch 00550: val_loss did not improve from 0.06192
#
# Epoch 00551: val_loss did not improve from 0.06192
#
# Epoch 00552: val_loss did not improve from 0.06192
#
# Epoch 00553: val_loss improved from 0.06192 to 0.06169, saving model to ./model/553-0.0617.hdf5
#
# Epoch 00554: val_loss improved from 0.06169 to 0.06116, saving model to ./model/554-0.0612.hdf5
#
# Epoch 00555: val_loss did not improve from 0.06116
#
# Epoch 00556: val_loss did not improve from 0.06116
#
# Epoch 00557: val_loss did not improve from 0.06116
#
# Epoch 00558: val_loss did not improve from 0.06116
#
# Epoch 00559: val_loss did not improve from 0.06116
#
# Epoch 00560: val_loss improved from 0.06116 to 0.06089, saving model to ./model/560-0.0609.hdf5
#
# Epoch 00561: val_loss did not improve from 0.06089
#
# Epoch 00562: val_loss did not improve from 0.06089
#
# Epoch 00563: val_loss did not improve from 0.06089
#
# Epoch 00564: val_loss did not improve from 0.06089
#
# Epoch 00565: val_loss did not improve from 0.06089
#
# Epoch 00566: val_loss improved from 0.06089 to 0.06040, saving model to ./model/566-0.0604.hdf5
#
# Epoch 00567: val_loss did not improve from 0.06040
#
# Epoch 00568: val_loss did not improve from 0.06040
#
# Epoch 00569: val_loss did not improve from 0.06040
#
# Epoch 00570: val_loss did not improve from 0.06040
#
# Epoch 00571: val_loss did not improve from 0.06040
#
# Epoch 00572: val_loss did not improve from 0.06040
#
# Epoch 00573: val_loss did not improve from 0.06040
#
# Epoch 00574: val_loss improved from 0.06040 to 0.05967, saving model to ./model/574-0.0597.hdf5
#
# Epoch 00575: val_loss did not improve from 0.05967
#
# Epoch 00576: val_loss did not improve from 0.05967
#
# Epoch 00577: val_loss did not improve from 0.05967
#
# Epoch 00578: val_loss did not improve from 0.05967
#
# Epoch 00579: val_loss did not improve from 0.05967
#
# Epoch 00580: val_loss improved from 0.05967 to 0.05793, saving model to ./model/580-0.0579.hdf5
#
# Epoch 00581: val_loss did not improve from 0.05793
#
# Epoch 00582: val_loss did not improve from 0.05793
#
# Epoch 00583: val_loss did not improve from 0.05793
#
# Epoch 00584: val_loss did not improve from 0.05793
#
# Epoch 00585: val_loss did not improve from 0.05793
#
# Epoch 00586: val_loss did not improve from 0.05793
#
# Epoch 00587: val_loss did not improve from 0.05793
#
# Epoch 00588: val_loss did not improve from 0.05793
#
# Epoch 00589: val_loss did not improve from 0.05793
#
# Epoch 00590: val_loss did not improve from 0.05793
#
# Epoch 00591: val_loss did not improve from 0.05793
#
# Epoch 00592: val_loss did not improve from 0.05793
#
# Epoch 00593: val_loss improved from 0.05793 to 0.05740, saving model to ./model/593-0.0574.hdf5
#
# Epoch 00594: val_loss did not improve from 0.05740
#
# Epoch 00595: val_loss did not improve from 0.05740
#
# Epoch 00596: val_loss did not improve from 0.05740
#
# Epoch 00597: val_loss did not improve from 0.05740
#
# Epoch 00598: val_loss improved from 0.05740 to 0.05697, saving model to ./model/598-0.0570.hdf5
#
# Epoch 00599: val_loss did not improve from 0.05697
#
# Epoch 00600: val_loss did not improve from 0.05697
#
# Epoch 00601: val_loss did not improve from 0.05697
#
# Epoch 00602: val_loss did not improve from 0.05697
#
# Epoch 00603: val_loss did not improve from 0.05697
#
# Epoch 00604: val_loss improved from 0.05697 to 0.05693, saving model to ./model/604-0.0569.hdf5
#
# Epoch 00605: val_loss did not improve from 0.05693
#
# Epoch 00606: val_loss did not improve from 0.05693
#
# Epoch 00607: val_loss improved from 0.05693 to 0.05659, saving model to ./model/607-0.0566.hdf5
#
# Epoch 00608: val_loss did not improve from 0.05659
#
# Epoch 00609: val_loss did not improve from 0.05659
#
# Epoch 00610: val_loss did not improve from 0.05659
#
# Epoch 00611: val_loss improved from 0.05659 to 0.05577, saving model to ./model/611-0.0558.hdf5
#
# Epoch 00612: val_loss did not improve from 0.05577
#
# Epoch 00613: val_loss did not improve from 0.05577
#
# Epoch 00614: val_loss improved from 0.05577 to 0.05545, saving model to ./model/614-0.0554.hdf5
#
# Epoch 00615: val_loss did not improve from 0.05545
#
# Epoch 00616: val_loss did not improve from 0.05545
#
# Epoch 00617: val_loss did not improve from 0.05545
#
# Epoch 00618: val_loss improved from 0.05545 to 0.05508, saving model to ./model/618-0.0551.hdf5
#
# Epoch 00619: val_loss did not improve from 0.05508
#
# Epoch 00620: val_loss did not improve from 0.05508
#
# Epoch 00621: val_loss improved from 0.05508 to 0.05488, saving model to ./model/621-0.0549.hdf5
#
# Epoch 00622: val_loss did not improve from 0.05488
#
# Epoch 00623: val_loss did not improve from 0.05488
#
# Epoch 00624: val_loss did not improve from 0.05488
#
# Epoch 00625: val_loss improved from 0.05488 to 0.05373, saving model to ./model/625-0.0537.hdf5
#
# Epoch 00626: val_loss did not improve from 0.05373
#
# Epoch 00627: val_loss did not improve from 0.05373
#
# Epoch 00628: val_loss improved from 0.05373 to 0.05349, saving model to ./model/628-0.0535.hdf5
#
# Epoch 00629: val_loss did not improve from 0.05349
#
# Epoch 00630: val_loss did not improve from 0.05349
#
# Epoch 00631: val_loss did not improve from 0.05349
#
# Epoch 00632: val_loss did not improve from 0.05349
#
# Epoch 00633: val_loss did not improve from 0.05349
#
# Epoch 00634: val_loss did not improve from 0.05349
#
# Epoch 00635: val_loss did not improve from 0.05349
#
# Epoch 00636: val_loss did not improve from 0.05349
#
# Epoch 00637: val_loss did not improve from 0.05349
#
# Epoch 00638: val_loss did not improve from 0.05349
#
# Epoch 00639: val_loss did not improve from 0.05349
#
# Epoch 00640: val_loss did not improve from 0.05349
#
# Epoch 00641: val_loss did not improve from 0.05349
#
# Epoch 00642: val_loss did not improve from 0.05349
#
# Epoch 00643: val_loss did not improve from 0.05349
#
# Epoch 00644: val_loss did not improve from 0.05349
#
# Epoch 00645: val_loss improved from 0.05349 to 0.05339, saving model to ./model/645-0.0534.hdf5
#
# Epoch 00646: val_loss did not improve from 0.05339
#
# Epoch 00647: val_loss did not improve from 0.05339
#
# Epoch 00648: val_loss improved from 0.05339 to 0.05297, saving model to ./model/648-0.0530.hdf5
#
# Epoch 00649: val_loss did not improve from 0.05297
#
# Epoch 00650: val_loss did not improve from 0.05297
#
# Epoch 00651: val_loss did not improve from 0.05297
#
# Epoch 00652: val_loss did not improve from 0.05297
#
# Epoch 00653: val_loss did not improve from 0.05297
#
# Epoch 00654: val_loss did not improve from 0.05297
#
# Epoch 00655: val_loss did not improve from 0.05297
#
# Epoch 00656: val_loss improved from 0.05297 to 0.05296, saving model to ./model/656-0.0530.hdf5
#
# Epoch 00657: val_loss did not improve from 0.05296
#
# Epoch 00658: val_loss did not improve from 0.05296
#
# Epoch 00659: val_loss did not improve from 0.05296
#
# Epoch 00660: val_loss did not improve from 0.05296
#
# Epoch 00661: val_loss did not improve from 0.05296
#
# Epoch 00662: val_loss improved from 0.05296 to 0.05167, saving model to ./model/662-0.0517.hdf5
#
# Epoch 00663: val_loss did not improve from 0.05167
#
# Epoch 00664: val_loss did not improve from 0.05167
#
# Epoch 00665: val_loss did not improve from 0.05167
#
# Epoch 00666: val_loss did not improve from 0.05167
#
# Epoch 00667: val_loss did not improve from 0.05167
#
# Epoch 00668: val_loss did not improve from 0.05167
#
# Epoch 00669: val_loss improved from 0.05167 to 0.05101, saving model to ./model/669-0.0510.hdf5
# Epoch 00670: val_loss did not improve from 0.05101
#
# Epoch 00671: val_loss improved from 0.05101 to 0.05058, saving model to ./model/671-0.0506.hdf5
#
# Epoch 00672: val_loss did not improve from 0.05058
#
# Epoch 00673: val_loss did not improve from 0.05058
#
# Epoch 00674: val_loss improved from 0.05058 to 0.05056, saving model to ./model/674-0.0506.hdf5
#
# Epoch 00675: val_loss did not improve from 0.05056
#
# Epoch 00676: val_loss did not improve from 0.05056
#
# Epoch 00677: val_loss improved from 0.05056 to 0.04946, saving model to ./model/677-0.0495.hdf5
#
# Epoch 00678: val_loss did not improve from 0.04946
#
# Epoch 00679: val_loss did not improve from 0.04946
#
# Epoch 00680: val_loss improved from 0.04946 to 0.04884, saving model to ./model/680-0.0488.hdf5
#
# Epoch 00681: val_loss did not improve from 0.04884
#
# Epoch 00682: val_loss did not improve from 0.04884
#
# Epoch 00683: val_loss did not improve from 0.04884
#
# Epoch 00684: val_loss did not improve from 0.04884
#
# Epoch 00685: val_loss did not improve from 0.04884
#
# Epoch 00686: val_loss did not improve from 0.04884
#
# Epoch 00687: val_loss did not improve from 0.04884
#
# Epoch 00688: val_loss did not improve from 0.04884
#
# Epoch 00689: val_loss did not improve from 0.04884
#
# Epoch 00690: val_loss did not improve from 0.04884
#
# Epoch 00691: val_loss did not improve from 0.04884
#
# Epoch 00692: val_loss did not improve from 0.04884
#
# Epoch 00693: val_loss did not improve from 0.04884
#
# Epoch 00694: val_loss improved from 0.04884 to 0.04840, saving model to ./model/694-0.0484.hdf5
#
# Epoch 00695: val_loss did not improve from 0.04840
#
# Epoch 00696: val_loss did not improve from 0.04840
#
# Epoch 00697: val_loss did not improve from 0.04840
#
# Epoch 00698: val_loss improved from 0.04840 to 0.04750, saving model to ./model/698-0.0475.hdf5
#
# Epoch 00699: val_loss improved from 0.04750 to 0.04749, saving model to ./model/699-0.0475.hdf5
#
# Epoch 00700: val_loss did not improve from 0.04749
#
# Epoch 00701: val_loss improved from 0.04749 to 0.04648, saving model to ./model/701-0.0465.hdf5
#
# Epoch 00702: val_loss improved from 0.04648 to 0.04529, saving model to ./model/702-0.0453.hdf5
#
# Epoch 00703: val_loss did not improve from 0.04529
#
# Epoch 00704: val_loss did not improve from 0.04529
#
# Epoch 00705: val_loss improved from 0.04529 to 0.04258, saving model to ./model/705-0.0426.hdf5
#
# Epoch 00706: val_loss improved from 0.04258 to 0.04160, saving model to ./model/706-0.0416.hdf5
#
# Epoch 00707: val_loss did not improve from 0.04160
#
# Epoch 00708: val_loss did not improve from 0.04160
#
# Epoch 00709: val_loss did not improve from 0.04160
#
# Epoch 00710: val_loss did not improve from 0.04160
#
# Epoch 00711: val_loss did not improve from 0.04160
#
# Epoch 00712: val_loss did not improve from 0.04160
#
# Epoch 00713: val_loss did not improve from 0.04160
#
# Epoch 00714: val_loss did not improve from 0.04160
#
# Epoch 00715: val_loss did not improve from 0.04160
#
# Epoch 00716: val_loss did not improve from 0.04160
#
# Epoch 00717: val_loss did not improve from 0.04160
#
# Epoch 00718: val_loss did not improve from 0.04160
#
# Epoch 00719: val_loss did not improve from 0.04160
#
# Epoch 00720: val_loss did not improve from 0.04160
#
# Epoch 00721: val_loss did not improve from 0.04160
#
# Epoch 00722: val_loss did not improve from 0.04160
#
# Epoch 00723: val_loss did not improve from 0.04160
#
# Epoch 00724: val_loss did not improve from 0.04160
#
# Epoch 00725: val_loss did not improve from 0.04160
#
# Epoch 00726: val_loss did not improve from 0.04160
#
# Epoch 00727: val_loss did not improve from 0.04160
#
# Epoch 00728: val_loss did not improve from 0.04160
#
# Epoch 00729: val_loss did not improve from 0.04160
#
# Epoch 00730: val_loss did not improve from 0.04160
#
# Epoch 00731: val_loss did not improve from 0.04160
#
# Epoch 00732: val_loss did not improve from 0.04160
#
# Epoch 00733: val_loss did not improve from 0.04160
#
# Epoch 00734: val_loss did not improve from 0.04160
#
# Epoch 00735: val_loss did not improve from 0.04160
#
# Epoch 00736: val_loss did not improve from 0.04160
#
# Epoch 00737: val_loss did not improve from 0.04160
#
# Epoch 00738: val_loss did not improve from 0.04160
#
# Epoch 00739: val_loss did not improve from 0.04160
#
# Epoch 00740: val_loss did not improve from 0.04160
#
# Epoch 00741: val_loss did not improve from 0.04160
#
# Epoch 00742: val_loss did not improve from 0.04160
#
# Epoch 00743: val_loss did not improve from 0.04160
#
# Epoch 00744: val_loss did not improve from 0.04160
#
# Epoch 00745: val_loss did not improve from 0.04160
#
# Epoch 00746: val_loss did not improve from 0.04160
#
# Epoch 00747: val_loss did not improve from 0.04160
#
# Epoch 00748: val_loss did not improve from 0.04160
#
# Epoch 00749: val_loss did not improve from 0.04160
#
# Epoch 00750: val_loss did not improve from 0.04160
#
# Epoch 00751: val_loss did not improve from 0.04160
#
# Epoch 00752: val_loss did not improve from 0.04160
#
# Epoch 00753: val_loss did not improve from 0.04160
#
# Epoch 00754: val_loss did not improve from 0.04160
#
# Epoch 00755: val_loss did not improve from 0.04160
#
# Epoch 00756: val_loss did not improve from 0.04160
#
# Epoch 00757: val_loss did not improve from 0.04160
#
# Epoch 00758: val_loss did not improve from 0.04160
#
# Epoch 00759: val_loss did not improve from 0.04160
#
# Epoch 00760: val_loss did not improve from 0.04160
#
# Epoch 00761: val_loss did not improve from 0.04160
#
# Epoch 00762: val_loss did not improve from 0.04160
#
# Epoch 00763: val_loss did not improve from 0.04160
#
# Epoch 00764: val_loss did not improve from 0.04160
#
# Epoch 00765: val_loss did not improve from 0.04160
#
# Epoch 00766: val_loss did not improve from 0.04160
#
# Epoch 00767: val_loss did not improve from 0.04160
#
# Epoch 00768: val_loss did not improve from 0.04160
#
# Epoch 00769: val_loss did not improve from 0.04160
#
# Epoch 00770: val_loss did not improve from 0.04160
#
# Epoch 00771: val_loss did not improve from 0.04160
#
# Epoch 00772: val_loss did not improve from 0.04160
#
# Epoch 00773: val_loss did not improve from 0.04160
#
# Epoch 00774: val_loss did not improve from 0.04160
#
# Epoch 00775: val_loss did not improve from 0.04160
#
# Epoch 00776: val_loss did not improve from 0.04160
#
# Epoch 00777: val_loss did not improve from 0.04160
#
# Epoch 00778: val_loss did not improve from 0.04160
#
# Epoch 00779: val_loss did not improve from 0.04160
#
# Epoch 00780: val_loss did not improve from 0.04160
#
# Epoch 00781: val_loss did not improve from 0.04160
#
# Epoch 00782: val_loss did not improve from 0.04160
#
# Epoch 00783: val_loss did not improve from 0.04160
#
# Epoch 00784: val_loss did not improve from 0.04160
#
# Epoch 00785: val_loss did not improve from 0.04160
#
# Epoch 00786: val_loss did not improve from 0.04160
#
# Epoch 00787: val_loss did not improve from 0.04160
#
# Epoch 00788: val_loss did not improve from 0.04160
#
# Epoch 00789: val_loss did not improve from 0.04160
#
# Epoch 00790: val_loss did not improve from 0.04160
#
# Epoch 00791: val_loss did not improve from 0.04160
#
# Epoch 00792: val_loss did not improve from 0.04160
#
# Epoch 00793: val_loss did not improve from 0.04160
#
# Epoch 00794: val_loss did not improve from 0.04160
#
# Epoch 00795: val_loss did not improve from 0.04160
#
# Epoch 00796: val_loss did not improve from 0.04160
#
# Epoch 00797: val_loss did not improve from 0.04160
#
# Epoch 00798: val_loss did not improve from 0.04160
#
# Epoch 00799: val_loss did not improve from 0.04160
#
# Epoch 00800: val_loss did not improve from 0.04160
#
# Epoch 00801: val_loss did not improve from 0.04160
#
# Epoch 00802: val_loss did not improve from 0.04160
#
# Epoch 00803: val_loss did not improve from 0.04160
#
# Epoch 00804: val_loss did not improve from 0.04160
#
# Epoch 00805: val_loss did not improve from 0.04160
#
# Epoch 00806: val_loss did not improve from 0.04160
