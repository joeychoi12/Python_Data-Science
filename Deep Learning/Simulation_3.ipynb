# %% [markdown]
# - 17 x 20 x 12 x 1
# - relu/tanh adam 30 10
# - 0.8511

# %%
import numpy as np
import tensorflow as tf
if type(tf.contrib) != type(tf):
    tf.contrib.warning = None
#케라스 import 
from keras.models import Sequential
from keras.layers import Dense

#실행할 때마다 같은 결과 출력 
seed =0 
np.random.seed(seed)
tf.set_random_seed(seed)

# 준비된 수술 환자 데이터를 불러들임
Data_set = np.loadtxt("dataset/ThoraricSurgery.csv", delimiter=",")
Data_set

# 환자의 기록과 수술 결과를 X와 Y로 구분하여 저장
X = Data_set[:,0:17]
Y = Data_set[:,17]

# 딥러닝 구조를 결정(모델을 설정하고 실행하는 부분)
model = Sequential()
model.add(Dense(20, input_dim=17, activation='relu'))
model.add(Dense(12, activation = 'tanh'))
model.add(Dense(1, activation='sigmoid'))

# 딥러닝 실행
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, epochs=30, batch_size=10)

# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# Epoch 1/30
# 470/470 [==============================] - 0s 332us/step - loss: 0.2064 - acc: 0.7319
# Epoch 2/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1424 - acc: 0.8511
# Epoch 3/30
# 470/470 [==============================] - 0s 55us/step - loss: 0.1338 - acc: 0.8511
# Epoch 4/30
# 470/470 [==============================] - 0s 55us/step - loss: 0.1307 - acc: 0.8511
# Epoch 5/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1290 - acc: 0.8511
# Epoch 6/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1279 - acc: 0.8511
# Epoch 7/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1276 - acc: 0.8511
# Epoch 8/30
# 470/470 [==============================] - 0s 51us/step - loss: 0.1270 - acc: 0.8511
# Epoch 9/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1266 - acc: 0.8511
# Epoch 10/30
# 470/470 [==============================] - 0s 55us/step - loss: 0.1268 - acc: 0.8511
# Epoch 11/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1262 - acc: 0.8511
# Epoch 12/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1261 - acc: 0.8511
# Epoch 13/30
# 470/470 [==============================] - 0s 55us/step - loss: 0.1256 - acc: 0.8511
# Epoch 14/30
# 470/470 [==============================] - 0s 51us/step - loss: 0.1261 - acc: 0.8511
# Epoch 15/30
# 470/470 [==============================] - 0s 55us/step - loss: 0.1255 - acc: 0.8511
# Epoch 16/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1256 - acc: 0.8511
# Epoch 17/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1257 - acc: 0.8511
# Epoch 18/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1258 - acc: 0.8511
# Epoch 19/30
# 470/470 [==============================] - 0s 51us/step - loss: 0.1255 - acc: 0.8511
# Epoch 20/30
# 470/470 [==============================] - 0s 55us/step - loss: 0.1255 - acc: 0.8511
# Epoch 21/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1256 - acc: 0.8511
# Epoch 22/30
# 470/470 [==============================] - 0s 57us/step - loss: 0.1250 - acc: 0.8511
# Epoch 23/30
# 470/470 [==============================] - 0s 51us/step - loss: 0.1256 - acc: 0.8511
# Epoch 24/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1253 - acc: 0.8511
# Epoch 25/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1252 - acc: 0.8511
# Epoch 26/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1256 - acc: 0.8511
# Epoch 27/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1253 - acc: 0.8511
# Epoch 28/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1256 - acc: 0.8511
# Epoch 29/30
# 470/470 [==============================] - 0s 60us/step - loss: 0.1255 - acc: 0.8511
# Epoch 30/30
# 470/470 [==============================] - 0s 53us/step - loss: 0.1250 - acc: 0.8511
# 470/470 [==============================] - 0s 66us/step
#
#  Accuracy: 0.8511
